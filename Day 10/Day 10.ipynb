# %%
# Split
# where
# clip
# Broadcasting
# Pandas Introduction

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = plt.imread(r'C:\Users\samiksha teotia\Desktop\Shih Tzu\images.webp')

# %%
shihtzu_arr = arr.copy()

# %%
plt.imshow(shihtzu_arr)

# %%
shihtzu_arr.shape
# Out:
# (480, 480, 3)

# %%
a = np.random.randint(0,255,(3,3,3))  #last m 3 hi rhega 
plt.imshow(a)

# %%
a = np.random.randint(0,255,(50,50,3))
plt.imshow(a)

# %%
while True:  #it will not run if false hoga while
    import numpy as np
    import matplotlib.pyplot as plt
    import time
    a = np.random.randint(0,255,(5,5,3))
    plt.imshow(a)
    plt.show()
    time.sleep(0.3)
    display(clear = True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 8
#       6 plt.imshow(a)
#       7 plt.show()
# ----> 8 time.sleep(0.3)
#       9 display(clear = True)
#
# KeyboardInterrupt:

# %%
a = np.random.randint(0,255,(4,4,3))
a
# Out:
# array([[[116,  87,  87],
#         [178,  89, 244],
#         [100,  36,  90],
#         [126,  49, 152]],
#
#        [[208, 124, 245],
#         [  1, 246, 130],
#         [ 82,  61,  28],
#         [184,   1, 254]],
#
#        [[201, 127,  86],
#         [ 55,   3, 192],
#         [206, 253,  48],
#         [ 23, 101,   7]],
#
#        [[198, 249, 182],
#         [167,  66, 239],
#         [106, 222, 228],
#         [113,   8, 161]]], dtype=int32)

# %%
np.split(a,2)
# Out:
# [array([[[116,  87,  87],
#          [178,  89, 244],
#          [100,  36,  90],
#          [126,  49, 152]],
#
#         [[208, 124, 245],
#          [  1, 246, 130],
#          [ 82,  61,  28],
#          [184,   1, 254]]], dtype=int32),
#  array([[[201, 127,  86],
#          [ 55,   3, 192],
#          [206, 253,  48],
#          [ 23, 101,   7]],
#
#         [[198, 249, 182],
#          [167,  66, 239],
#          [106, 222, 228],
#          [113,   8, 161]]], dtype=int32)]

# %%
final_arr = np.split(a,2)
len(final_arr)
# Out:
# 2

# %%
plt.imshow(final_arr[1])

# %%
arr_1 = np.split(a,2,axis = 1)

# %%
len(arr_1)
# Out:
# 2

# %%
a
# Out:
# array([[[116,  87,  87],
#         [178,  89, 244],
#         [100,  36,  90],
#         [126,  49, 152]],
#
#        [[208, 124, 245],
#         [  1, 246, 130],
#         [ 82,  61,  28],
#         [184,   1, 254]],
#
#        [[201, 127,  86],
#         [ 55,   3, 192],
#         [206, 253,  48],
#         [ 23, 101,   7]],
#
#        [[198, 249, 182],
#         [167,  66, 239],
#         [106, 222, 228],
#         [113,   8, 161]]], dtype=int32)

# %%
arr_3_part = np.split(a,3,axis = 2)

# %%
arr_3_part
# Out:
# [array([[[116],
#          [178],
#          [100],
#          [126]],
#
#         [[208],
#          [  1],
#          [ 82],
#          [184]],
#
#         [[201],
#          [ 55],
#          [206],
#          [ 23]],
#
#         [[198],
#          [167],
#          [106],
#          [113]]], dtype=int32),
#  array([[[ 87],
#          [ 89],
#          [ 36],
#          [ 49]],
#
#         [[124],
#          [246],
#          [ 61],
#          [  1]],
#
#         [[127],
#          [  3],
#          [253],
#          [101]],
#
#         [[249],
#          [ 66],
#          [222],
#          [  8]]], dtype=int32),
#  array([[[ 87],
#          [244],
#          [ 90],
#          [152]],
#
#         [[245],
#          [130],
#          [ 28],
#          [254]],
#
#         [[ 86],
#          [192],
#          [ 48],
#          [  7]],
#
#         [[182],
#          [239],
#          [228],
#          [161]]], dtype=int32)]

# %%
plt.imshow(a)

# %%
len(arr_3_part)
# Out:
# 3

# %%
plt.imshow(arr_3_part[0])

# %%
plt.imshow(arr_3_part[1])

# %%
plt.imshow(arr_3_part[2])

# %%
arr.shape
# Out:
# (480, 480, 3)

# %%
plt.imshow(np.split(arr,3,axis = 2)[2])

# %%
plt.imshow(np.split(arr,2,axis = 0)[1])

# %%
plt.imshow(np.split(arr,2,axis = 0)[0])

# %%
arr.shape
# Out:
# (480, 480, 3)

# %%
1000//3
# Out:
# 333

# %%
plt.imshow(arr[:,:333,:])

# %%
plt.imshow(arr[:,333:333*2,:])

# %%
plt.imshow(arr[:,333*1:,:])

# %%
# where
# clip
# Broadcasting

# %%
a = np.random.randint(1,500,(4,4))
a
# Out:
# array([[155,  17, 311, 481],
#        [201, 415, 184, 158],
#        [476, 349, 352,  69],
#        [221, 330, 101, 342]], dtype=int32)

# %%
np.where(a>200)
# Out:
# (array([0, 0, 1, 1, 2, 2, 2, 3, 3, 3]), array([2, 3, 0, 1, 0, 1, 2, 0, 1, 3]))

# %%
np.where(a>200,'High Sales','Low Sales')
# Out:
# array([['Low Sales', 'Low Sales', 'High Sales', 'High Sales'],
#        ['High Sales', 'High Sales', 'Low Sales', 'Low Sales'],
#        ['High Sales', 'High Sales', 'High Sales', 'Low Sales'],
#        ['High Sales', 'High Sales', 'Low Sales', 'High Sales']],
#       dtype='<U10')

# %%
np.where(a>200,'High Sales',a)
# Out:
# array([['155', '17', 'High Sales', 'High Sales'],
#        ['High Sales', 'High Sales', '184', '158'],
#        ['High Sales', 'High Sales', 'High Sales', '69'],
#        ['High Sales', 'High Sales', '101', 'High Sales']], dtype='<U11')

# %%
a
# Out:
# array([[155,  17, 311, 481],
#        [201, 415, 184, 158],
#        [476, 349, 352,  69],
#        [221, 330, 101, 342]], dtype=int32)

# %%
np.clip(a,100,250) # outliers remove/replace
# Out:
# array([[155, 100, 250, 250],
#        [201, 250, 184, 158],
#        [250, 250, 250, 100],
#        [221, 250, 101, 250]], dtype=int32)

# %%
# Broadcasting

# %%
a = np.random.randint(1,10,7)
b = np.random.randint(1,10,(2,7))
print(a)
print('-------\n\n')
print(b)
# Out:
# [7 1 9 9 1 2 3]
# -------
#
#
# [[7 4 4 6 8 5 9]
#  [9 9 8 3 5 5 3]]

# %%
(a + b)
# Out:
# array([[14,  5, 13, 15,  9,  7, 12],
#        [16, 10, 17, 12,  6,  7,  6]], dtype=int32)

# %%
a * b
# Out:
# array([[49,  4, 36, 54,  8, 10, 27],
#        [63,  9, 72, 27,  5, 10,  9]], dtype=int32)

# %%
a - b
# Out:
# array([[ 0, -3,  5,  3, -7, -3, -6],
#        [-2, -8,  1,  6, -4, -3,  0]], dtype=int32)

# %%
a = np.random.randint(1,10,7)
b = np.random.randint(1,10,(7,7))
print(a)
print('-------\n\n')
print(b)
# Out:
# [4 3 3 9 9 8 2]
# -------
#
#
# [[9 1 5 4 8 5 1]
#  [9 7 3 2 2 4 6]
#  [6 7 8 3 4 5 4]
#  [9 2 6 3 4 7 4]
#  [1 8 8 7 6 1 5]
#  [9 4 1 7 5 9 3]
#  [9 6 1 1 2 8 1]]

# %%
a + b
# Out:
# array([[13,  4,  8, 13, 17, 13,  3],
#        [13, 10,  6, 11, 11, 12,  8],
#        [10, 10, 11, 12, 13, 13,  6],
#        [13,  5,  9, 12, 13, 15,  6],
#        [ 5, 11, 11, 16, 15,  9,  7],
#        [13,  7,  4, 16, 14, 17,  5],
#        [13,  9,  4, 10, 11, 16,  3]], dtype=int32)

# %%
a = np.random.randint(1,10,7)
b = np.random.randint(1,10,(1,7))
print(a)
print('-------\n\n')
print(b)
# Out:
# [4 2 3 4 1 2 1]
# -------
#
#
# [[5 4 5 5 1 4 8]]

# %%
a + b
# Out:
# array([[9, 6, 8, 9, 2, 6, 9]], dtype=int32)

# %%
a = np.random.randint(1,10,(7,1))
b = np.random.randint(1,10,(1,7))
print(a)
print('-------\n\n')
print(b)
# Out:
# [[6]
#  [6]
#  [5]
#  [2]
#  [9]
#  [8]
#  [4]]
# -------
#
#
# [[5 4 8 9 2 5 4]]

# %%
a - b
# Out:
# array([[ 1,  2, -2, -3,  4,  1,  2],
#        [ 1,  2, -2, -3,  4,  1,  2],
#        [ 0,  1, -3, -4,  3,  0,  1],
#        [-3, -2, -6, -7,  0, -3, -2],
#        [ 4,  5,  1,  0,  7,  4,  5],
#        [ 3,  4,  0, -1,  6,  3,  4],
#        [-1,  0, -4, -5,  2, -1,  0]], dtype=int32)

# %%
a = np.random.randint(1,10,(1,1))
b = np.random.randint(1,10,(5,7))
print(a)
print('-------\n\n')
print(b)
# Out:
# [[3]]
# -------
#
#
# [[7 8 8 7 1 3 5]
#  [9 2 7 7 9 6 4]
#  [9 4 9 9 7 6 2]
#  [1 4 1 2 1 1 2]
#  [6 3 5 5 5 2 1]]

# %%
a - b
# Out:
# array([[-4, -5, -5, -4,  2,  0, -2],
#        [-6,  1, -4, -4, -6, -3, -1],
#        [-6, -1, -6, -6, -4, -3,  1],
#        [ 2, -1,  2,  1,  2,  2,  1],
#        [-3,  0, -2, -2, -2,  1,  2]], dtype=int32)

# %%
a = np.random.randint(1,10,(1,1,5))
b = np.random.randint(1,10,(5,5,5))
print(a)
print('-------\n\n')
print(b)
# Out:
# [[[7 5 1 8 9]]]
# -------
#
#
# [[[3 2 2 5 4]
#   [1 9 3 2 4]
#   [2 6 8 4 3]
#   [7 7 2 2 1]
#   [5 2 6 2 2]]
#
#  [[4 6 1 7 5]
#   [6 7 2 7 4]
#   [1 4 6 3 3]
#   [1 3 5 3 3]
#   [2 8 6 2 6]]
#
#  [[1 7 5 2 1]
#   [2 4 7 6 9]
#   [5 5 8 4 7]
#   [3 7 5 1 6]
#   [6 2 1 6 8]]
#
#  [[7 9 6 9 4]
#   [1 6 9 3 4]
#   [2 2 1 5 7]
#   [9 1 8 3 7]
#   [4 9 3 9 8]]
#
#  [[1 1 7 9 3]
#   [4 1 2 3 6]
#   [5 5 2 5 4]
#   [6 1 5 3 7]
#   [1 6 6 4 5]]]

# %%
a - b
# Out:
# array([[[ 4,  3, -1,  3,  5],
#         [ 6, -4, -2,  6,  5],
#         [ 5, -1, -7,  4,  6],
#         [ 0, -2, -1,  6,  8],
#         [ 2,  3, -5,  6,  7]],
#
#        [[ 3, -1,  0,  1,  4],
#         [ 1, -2, -1,  1,  5],
#         [ 6,  1, -5,  5,  6],
#         [ 6,  2, -4,  5,  6],
#         [ 5, -3, -5,  6,  3]],
#
#        [[ 6, -2, -4,  6,  8],
#         [ 5,  1, -6,  2,  0],
#         [ 2,  0, -7,  4,  2],
#         [ 4, -2, -4,  7,  3],
#         [ 1,  3,  0,  2,  1]],
#
#        [[ 0, -4, -5, -1,  5],
#         [ 6, -1, -8,  5,  5],
#         [ 5,  3,  0,  3,  2],
#         [-2,  4, -7,  5,  2],
#         [ 3, -4, -2, -1,  1]],
#
#        [[ 6,  4, -6, -1,  6],
#         [ 3,  4, -1,  5,  3],
#         [ 2,  0, -1,  3,  5],
#         [ 1,  4, -4,  5,  2],
#         [ 6, -1, -5,  4,  4]]], dtype=int32)

# %%
#Introduction to Pandas

# %%
#Data Science
#data : Explore (Exploratory Data Analysis) EDA
#Excel : EDA
#PowerBI : EDA
#SQL : EDA
#Python : EDA

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %%
import random
products = ['Chair','Tables','Laptop','Mobile Phones','Charger']
region = ['East','West','North','South']
#date column
all_date = pd.date_range('01-01-2025','23-07-2025')
data = {'Order_id':range(1,1001),
        'Date':random.choices(all_date,k = 1000),
        'Region Name':random.choices(region,k = 1000),
        'Product Name':random.choices(products,k = 1000),
        'Sales':np.random.randint(100,10000,1000),
        'Qty':np.random.randint(1,10,1000),
        'Profit':np.random.randint(-10000,10000,1000)}
table = pd.DataFrame(data)
table
# Out:
#      Order_id       Date Region Name   Product Name  Sales  Qty  Profit
# 0           1 2025-03-16        East         Tables   9623    6   -6729
# 1           2 2025-04-23        West          Chair   2938    5   -3761
# 2           3 2025-01-27        West         Tables   8596    6   -3899
# 3           4 2025-03-12       North  Mobile Phones   5479    3    9370
# 4           5 2025-04-08        West         Laptop   9114    2    3175
# ..        ...        ...         ...            ...    ...  ...     ...
# 995       996 2025-04-30       North        Charger    321    7    8754
# 996       997 2025-04-20        East         Laptop   7412    4   -6662
# 997       998 2025-05-02        West          Chair   9767    4   -3398
# 998       999 2025-06-15        East         Tables   2481    6   -3076
# 999      1000 2025-04-16        West         Tables   3821    3   -3573
#
# [1000 rows x 7 columns]

# %%
 #top data : by default 5 dekhata h
table.head()
# Out:
#    Order_id       Date Region Name   Product Name  Sales  Qty  Profit
# 0         1 2025-03-16        East         Tables   9623    6   -6729
# 1         2 2025-04-23        West          Chair   2938    5   -3761
# 2         3 2025-01-27        West         Tables   8596    6   -3899
# 3         4 2025-03-12       North  Mobile Phones   5479    3    9370
# 4         5 2025-04-08        West         Laptop   9114    2    3175

# %%
table.head(10)
# Out:
#    Order_id       Date Region Name   Product Name  Sales  Qty  Profit
# 0         1 2025-03-16        East         Tables   9623    6   -6729
# 1         2 2025-04-23        West          Chair   2938    5   -3761
# 2         3 2025-01-27        West         Tables   8596    6   -3899
# 3         4 2025-03-12       North  Mobile Phones   5479    3    9370
# 4         5 2025-04-08        West         Laptop   9114    2    3175
# 5         6 2025-01-31       South        Charger   7949    6    9471
# 6         7 2025-01-20        West         Laptop   9093    8   -4191
# 7         8 2025-07-03       North         Tables   8418    3   -1598
# 8         9 2025-04-05        West         Laptop   1933    1    7935
# 9        10 2025-03-12        West          Chair    325    5   -4360

# %%
#bottom data : by default 5 dekhata h
table.tail()
# Out:
#      Order_id       Date Region Name Product Name  Sales  Qty  Profit
# 995       996 2025-04-30       North      Charger    321    7    8754
# 996       997 2025-04-20        East       Laptop   7412    4   -6662
# 997       998 2025-05-02        West        Chair   9767    4   -3398
# 998       999 2025-06-15        East       Tables   2481    6   -3076
# 999      1000 2025-04-16        West       Tables   3821    3   -3573

# %%
table.tail(10)
# Out:
#      Order_id       Date Region Name   Product Name  Sales  Qty  Profit
# 990       991 2025-03-11        East          Chair   7157    4    2096
# 991       992 2025-03-02        East         Laptop   6455    3    9229
# 992       993 2025-04-20        West  Mobile Phones   3551    8   -4987
# 993       994 2025-03-28       South         Laptop   7059    4   -1877
# 994       995 2025-04-18       North        Charger   6392    3    6112
# 995       996 2025-04-30       North        Charger    321    7    8754
# 996       997 2025-04-20        East         Laptop   7412    4   -6662
# 997       998 2025-05-02        West          Chair   9767    4   -3398
# 998       999 2025-06-15        East         Tables   2481    6   -3076
# 999      1000 2025-04-16        West         Tables   3821    3   -3573

# %%
table.tail(7)
# Out:
#      Order_id       Date Region Name Product Name  Sales  Qty  Profit
# 993       994 2025-03-28       South       Laptop   7059    4   -1877
# 994       995 2025-04-18       North      Charger   6392    3    6112
# 995       996 2025-04-30       North      Charger    321    7    8754
# 996       997 2025-04-20        East       Laptop   7412    4   -6662
# 997       998 2025-05-02        West        Chair   9767    4   -3398
# 998       999 2025-06-15        East       Tables   2481    6   -3076
# 999      1000 2025-04-16        West       Tables   3821    3   -3573

# %%
table.sample() #it will show random data
# Out:
#      Order_id       Date Region Name Product Name  Sales  Qty  Profit
# 143       144 2025-06-11        East      Charger    132    4    9148

# %%
table.sample(5)
# Out:
#      Order_id       Date Region Name Product Name  Sales  Qty  Profit
# 613       614 2025-02-27       North       Tables    368    5     276
# 581       582 2025-02-06       South       Tables   1070    3    9586
# 142       143 2025-03-09        East        Chair   7280    3    3767
# 85         86 2025-04-07       North       Tables   8404    1   -2399
# 437       438 2025-05-02       South       Laptop   4030    9   -9371

# %%
#Information:- about dataset
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_id      1000 non-null   int64
#  1   Date          1000 non-null   datetime64[ns]
#  2   Region Name   1000 non-null   object
#  3   Product Name  1000 non-null   object
#  4   Sales         1000 non-null   int32
#  5   Qty           1000 non-null   int32
#  6   Profit        1000 non-null   int32
# dtypes: datetime64[ns](1), int32(3), int64(1), object(2)
# memory usage: 43.1+ KB

# %%
table.columns
# Out:
# Index(['Order_id', 'Date', 'Region Name', 'Product Name', 'Sales', 'Qty',
#        'Profit'],
#       dtype='object')

# %%
table.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#isna(): it will check nan value counts
table.isna()
# Out:
#      Order_id   Date  Region Name  Product Name  Sales    Qty  Profit
# 0       False  False        False         False  False  False   False
# 1       False  False        False         False  False  False   False
# 2       False  False        False         False  False  False   False
# 3       False  False        False         False  False  False   False
# 4       False  False        False         False  False  False   False
# ..        ...    ...          ...           ...    ...    ...     ...
# 995     False  False        False         False  False  False   False
# 996     False  False        False         False  False  False   False
# 997     False  False        False         False  False  False   False
# 998     False  False        False         False  False  False   False
# 999     False  False        False         False  False  False   False
#
# [1000 rows x 7 columns]

# %%
table.isna().value_counts()
# Out:
# Order_id  Date   Region Name  Product Name  Sales  Qty    Profit
# False     False  False        False         False  False  False     1000
# Name: count, dtype: int64

# %%
#isna() and isnull() is same 
table.isnull()
# Out:
#      Order_id   Date  Region Name  Product Name  Sales    Qty  Profit
# 0       False  False        False         False  False  False   False
# 1       False  False        False         False  False  False   False
# 2       False  False        False         False  False  False   False
# 3       False  False        False         False  False  False   False
# 4       False  False        False         False  False  False   False
# ..        ...    ...          ...           ...    ...    ...     ...
# 995     False  False        False         False  False  False   False
# 996     False  False        False         False  False  False   False
# 997     False  False        False         False  False  False   False
# 998     False  False        False         False  False  False   False
# 999     False  False        False         False  False  False   False
#
# [1000 rows x 7 columns]
